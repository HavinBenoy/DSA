# %% [markdown]
# Selection Sort Algorithm
#
#
# Problem Statement: Given an array of N integers, write a program to implement the Selection sorting algorithm.

# %% [markdown]
# Example 1:
# Input: N = 6, array[] = {13,46,24,52,20,9}
# Output: 9,13,20,24,46,52
# Explanation: After sorting the array is: 9, 13, 20, 24, 46, 52
#
# Example 2:
# Input: N=5, array[] = {5,4,3,2,1}
# Output: 1,2,3,4,5
# Explanation: After sorting the array is: 1, 2, 3, 4, 5

# %% [markdown]
# Approach: Here we will find the most minimum element in a list then swap it with the ith (from zero to n-2) position, then continue by checking the rest of the array and performs the swapping operations accordingly.

# %%
# My solution:

def selection_sort(arr):
    for i in range (len(arr)-1):
        # Finding the index of the minimum value
        min_index = i
        for j in range(i+1,len(arr)):
            if arr[j]<arr[min_index]:
                min_index = j
        
        # swapping
        temp = arr[i]
        arr[i] = arr[min_index]
        arr[min_index] = temp
    return arr

k = list(map(int,input("Enter the array numbers with a space in between").split()))
print(f"Given list : {k}")
sorted_list = selection_sort(k)
print(f"sorted list : {sorted_list}")
# Out:
# Given list : [13, 46, 24, 52, 20, 9, 88, 1, 267]
# sorted list : [1, 9, 13, 20, 24, 46, 52, 88, 267]

# %%
# solution : same as my solution above but a bit more efficient swapping technique is used here. 

def selection_sort(arr):
    n = len(arr)

    # Traverse through all array elements
    for i in range(n - 1):
        min_index = i  # Assume current index is the minimum

        # Find the minimum element in the remaining array
        for j in range(i + 1, n):
            if arr[j] < arr[min_index]:
                min_index = j  # Update min_index if smaller is found

        # Swap the found minimum with the first element of unsorted part if they are not equal
        if min_index != i:
            arr[i], arr[min_index] = arr[min_index], arr[i]

    # Print the sorted array
    print("After selection sort:")
    print(*arr)


# Driver code
arr = [13, 46, 24, 52, 20, 9]

# Print array before sorting
print("Before selection sort:")
print(*arr)

# The asterisk (*) is the unpacking operator. 
# Instead of printing the array as a list with brackets and commas (e.g., [13, 46, 24]),
#  it "unpacks" the elements to print them as a space-separated sequence (e.g., 13 46 24)

# Call selection sort
selection_sort(arr)
# Out:
# Before selection sort:
# 13 46 24 52 20 9
# After selection sort:
# 9 13 20 24 46 52
