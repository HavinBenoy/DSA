# %%
N = int(input("Enter an input number: \n"))

for i in list(range(1,N+1)) + list(range(N-1,0,-1)):
    print("* " * i)
# Out:
# *
# * *
# * * *
# * *
# *

# %%
# PATTERN 10 revision

def pattern_10(n):
    for i in range(1,n+1):
        print("* "*i)
    for i in range(n-1,0,-1):
        print("* "*i)


def pattern_10_corrective (n):
    for i in list(range(1,n+1)) + list(range(n-1,0,-1)):
        print("* " *i)


n = 5
pattern_10_corrective(n)
# Out:
# *
# * *
# * * *
# * * * *
# * * * * *
# * * * *
# * * *
# * *
# *
