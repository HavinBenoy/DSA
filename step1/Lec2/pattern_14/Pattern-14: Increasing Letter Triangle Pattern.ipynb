# %%
# To print the alphabets we use the chr() function that takes the ASCII value as an argument.
#  'A'- has the ASCII value of 65 and 'a' has the ASCII value of 97. and others accordingly.

N = int(input("Enter an input number: "))

for i in range(1,N+1):
    for j in range(i):
        print(chr(65+j), end = " ")
    print()
# Out:
# A
# A B
# A B C
# A B C D
# A B C D E

# %%
def pattern_14(n):
    for i in range(1,n+1):
        for j in range(i):
            print(chr(65+j), end = " ")
        print()

pattern_14(5)
# Out:
# A
# A B
# A B C
# A B C D
# A B C D E
