# %% [markdown]
# Problem :
#
# 205. Isomorphic Strings
#
# Given two strings s and t, determine if they are isomorphic.
#
# Two strings s and t are isomorphic if the characters in s can be replaced to get t.
#
# All occurrences of a character must be replaced with another character while preserving the order of characters. No two characters may map to the same character, but a character may map to itself.

# %% [markdown]
# Example 1:
#
# Input: s = "egg", t = "add"
#
# Output: true
#
# Explanation:
#
# The strings s and t can be made identical by:
#
# Mapping 'e' to 'a'.
# Mapping 'g' to 'd'.
#
#
#
#
#
#
#
# Example 2:
#
# Input: s = "f11", t = "b23"
#
# Output: false
#
# Explanation:
#
# The strings s and t can not be made identical as '1' needs to be mapped to both '2' and '3'.
#
#
#
#
#
#
#
# Example 3:
#
# Input: s = "paper", t = "title"
#
# Output: true

# %%
# My solution

def is_isomorphic(str1, str2):

    if len(list(set(str1))) != len(list(set(str2))):
        return False
    result = list(str2)
    for i in range(len(str1)):
        actual_char = str1[i]
        corresponding_char = str2[i]

        for j in range(len(str1)):
            if str1[j]== actual_char and str2[j]==corresponding_char:
                result[j]=actual_char
    
    if ''.join(result)==str1:
        return True
    return False

str1 = "title"
str2 = "paper"


if is_isomorphic(str1, str2):
    print("words are isomorphic")
else:
    print("words are not isomorphic")
# Out:
# 5
# words are isomorphic

# %%
# Solution : Optimal Solution

def is_isomorphic(s, t):

    if len(s) != len(t):
        return False

    s_to_t = {}
    t_to_s = {}

    for i in range(len(s)):
        char_s = s[i]
        char_t = t[i]

        # Check s -> t mapping
        if char_s in s_to_t and s_to_t[char_s] != char_t:
            return False

        # Check t -> s mapping
        if char_t in t_to_s and t_to_s[char_t] != char_s:
            return False

        # Create mappings
        s_to_t[char_s] = char_t
        t_to_s[char_t] = char_s

    return True

str1 = "title"
str2 = "paper"


if is_isomorphic(str1, str2):
    print("words are isomorphic")
else:
    print("words are not isomorphic")
# Out:
# words are isomorphic
